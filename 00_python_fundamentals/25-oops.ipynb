# %% [markdown]
# # OOPS

# %% [markdown]
# 1. Pocedural Programming (functional or function based programming) -> makes reusability using functions.
#
# 2. OOP -> (using classes and objects to solve problems) - Mapping real world objects with code.
# (object is a real world entity like pen, car, book, mouse)
#
# ## class and object
#         class -> class is a blueprint of an object or to create an object. class created once it tells how the object will look like.
#
#         object -> object i an instance of class. objects are the actual things takes space in memory.
#
#     - class doesn't takes space in memory because it is just a blueprint it is overall design i can say.
#
# syntax to create a class:
# class ClassName:
#     => features or methods or attributes
#
# class is a blueprint and blueprint has 2 things first is properties/attributes(variables or values) and second is behaviours/methods

# %%
class Student:
    subject = "Python"
    college = "XYZ"
    year = "4th"


student1 = Student()
student2 = Student()
print(student1)
print(student2)

# %%
print(student1.subject)
print(student2.year)
# Out:
# Python
# 4th

# %%
print(type(student1))
# Out:
# <class '__main__.Student'>

# %% [markdown]
# ## Constructor
#
# __init__ Method
#
# Constructor - sepcial method or functions that constructs or creates objects.
#
# __init__ method - special method (constructor) that is used to initialize our object. it is a special method which gets called autmatically everytime we creates an object.
#         if we don't write init method python will create it automatically
#
# ### Self parameter:
# it is storing the current instance of the class basically means it is refering to the current object.
#
# it is used when we want to refer properties and methods and attributes of the current object or we want to use properties of current object.

# %%
import random


class Student:

    def __init__(self, name, email, password):  # parameterized constructor
        print("I am a constructor")
        # print(self)  # <__main__.Student object at 0x000002DE83A4E510>
        self.name = name
        self.email = email
        self.password = password

        id = random.random() + 1
        self._id = id

    # instance methods
    def get_id(self):
        return self._id


s1 = Student("krish kumar", "krish@gmail.com", "Krish@9661")
s2 = Student("ankit kumar", "ankit@gmail.com", "ankit@9661")
s3 = Student("raj kumar", "raj@gmail.com", "raj@9661")
print(s1.name)
print(s1.email)
print(s1.password)

print(s1.get_id())
print(s2.get_id())
print(s3.get_id())
# Out:
# I am a constructor
# I am a constructor
# I am a constructor
# krish kumar
# krish@gmail.com
# Krish@9661
# 1.5533715813054645
# 1.4244258275796042
# 1.7807659504933624

# %% [markdown]
# ## Types of constructor
#
# ### 1. default -> 1 parameter = self
# ### 2. parameterized -> self and different parameters
#
# in python in a class there can be only one constructor

# %%
class Student:
    def __init__(self, name):
        print("Constructor one")

    def __init__(self):
        print("Constructor two")

    def __init__(self, name):
        print("Constructor three")


s1 = Student("krish")
# in case if we write multiple constructor in a class last constructor will be considered
# Out:
# Constructor three

# %% [markdown]
# ## Attributes:
# ##
# ### There are 2 types of attributes in python:
# #### 1. class attributes: attribute belong to class. -> common
# #### 2. instance attributes: attribute which belong to object. -> unique
#
# eg:
#   #####  name, age, city -> instance attribute
#   #####  college_name -> class attribute

# %%
class Student:
    college_name = "Shobhit University"  # class attributes
    PI = 3.1

    def __init__(self, name, age, city):
        self.name = name  # instance attributes
        self.age = age
        self.city = city
        self.PI = 3.14


s1 = Student("krish", 21, "Delhi")

print(s1.name)
print(s1.age)
print(s1.city)
print(s1.college_name)  # common  - no memory overhead

# print(Student.name)  # error -  type object 'Student' has no attribute 'name'

print(s1.college_name)

print(Student.college_name)

print(
    s1.PI
)  # 3.14 - instance value (instance attribute has higher priority than class attribute)
print(Student.PI)  # 3.1 # class attribute
# Out:
# krish
# 21
# Delhi
# Shobhit University
# Shobhit University
# Shobhit University
# 3.14
# 3.1

# %% [markdown]
# ## Methods
# ######
# ### 3 Categories of Methods:
# ####     - instance Method
# ####     - class Method
# ####     - static Method

# %%
"""
instance                class                       static
1. 1st param is self    1st paramter is cls         we create it when we
                                                    don't want to use class
2. can access class &   access class attributes     or instance attributes
instance attributes
                        we use decorators in        no compulsury parameters like
                        class method                self and cls
                        @classmethod
                                                    they cann't access instance
                                                    attributes or class
                                                    attributes

                                                    used special decorator called
                                                    @staticmethod
                                                    to make method static
                                                    @staticmethod decorator converts
                                                    our normal method into static
                                                    method

                                                    so the static methods are
                                                    the methods which do not
                                                    belong to the class they do not
                                                    belong to any instance
                                                    they are standalone function
                                                    in our class


"""
# Out:
# '\ninstance                class               static\n1. 1st param is self\n\n\n\n\n'

# %%
# instance method
class Laptop:
    storage_type = "SSD"

    def __init__(self, RAM, storage):
        self.RAM = RAM
        self.storage = storage

    def get_info(self):  # instance method
        print(f"Laptop has {self.RAM} RAM & {self.storage} {self.storage_type}")
        print(f"Laptop has {self.RAM} RAM & {self.storage} {Laptop.storage_type}")


l1 = Laptop("16GB", "512GB")
l2 = Laptop("8GB", "256GB")

l1.get_info()
l2.get_info()
# Out:
# Laptop has 16GB RAM & 512GB SSD
# Laptop has 16GB RAM & 512GB SSD
# Laptop has 8GB RAM & 256GB SSD
# Laptop has 8GB RAM & 256GB SSD

# %%
# class method
class Laptop:
    storage_type = "SSD"

    def __init__(self, RAM, storage):
        self.RAM = RAM
        self.storage = storage

    def get_info(self):  # instance method
        print(f"Laptop has {self.RAM} RAM and {self.storage} {self.storage_type}")

    @classmethod
    def get_storage_type(cls):  # class method
        print(cls.storage_type)


l1 = Laptop("32GB", "1TB")
l1.get_info()
l1.get_storage_type()
Laptop.get_storage_type()

# decorator - decorator is basically is a function that takes another function and chnages its behavior and return
# Out:
# Laptop has 32GB RAM and 1TB SSD
# SSD
# SSD

# %%
# static method
class Laptop:
    storage_type = "SSD"

    def __init__(self, RAM, storage):
        self.RAM = RAM
        self.storage = storage

    def get_info(self):  # instance attribute
        print(f"Laptop has {self.RAM} RAM and {self.storage} {self.storage_type}")

    @classmethod
    def get_storage_type(cls): #class method
        print(f"The Laptop has {cls.storage_type} storage")

    @staticmethod
    def calculate_price(price, discount):
        print(f"Laptop price is {price - (price * discount / 100)}")


l1 = Laptop("64GB", "2TB")
l1.calculate_price(40_000, 10)
Laptop.calculate_price(50_000, 10)
# Out:
# Laptop price is 36000.0
# Laptop price is 45000.0

# %% [markdown]
# ## Problem - Product Store
# #####
# ##### Desing & create an online store for produts (name, price)
# ##### Track total products being created.
# ##### Create a static method to calculate discount on each product based on a % parameter

# %%
class Product:
    count = 0

    def __init__(self, name, price):
        self.name = name
        self.price = price
        Product.count += 1

    def get_info(self):  # instance method
        print(f"The Price of {self.name} is {self.price}")

    @classmethod
    def get_count(cls):
        print(f"Total Products in store = {cls.count}")

    @staticmethod
    def calculate_discount(price, discount):
        print(f"Discounted Price = {price - (price * discount / 100)}")


p1 = Product("Phone", 10_000)
p2 = Product("laptop", 40_000)
p3 = Product("pen", 10)
p4 = Product("book", 450)
p1.get_info()
print(p1.count)
print(p4.count)
print(Product.count)
p1.calculate_discount(10_000, 10)
Product.calculate_discount(p2.price, 22)
p4.calculate_discount(p4.price, 6)
Product.get_count()
# Out:
# The Price of Phone is 10000
# 4
# 4
# 4
# Discounted Price = 9000.0
# Discounted Price = 31200.0
# Discounted Price = 423.0
# Total Products in store = 4

# %% [markdown]
# ## OOP Pillars
# ##### 1. Encapsulation: wrapping up of data and its related properties and attributes and methods in a single unit called class
#     - in encapsulation we do also data hiding - data hiding basically means hiding sensitive or secure information from the user.
#
#     => public data - accessible inside and outside everywhere in the class
#     => protected data - accessible inside class and its related subclass
#     => Private data - accessible inside the current class only.
#
# ##### 2. Abstraction: Hiding unneccessary details from the user and showing only necessary details.
#
# ##### 3. inheritance: Transfer properties of a class into its subclass or child class
#
# ##### 4. Polymorphism: use same functions and operators in multiple ways by changing its form.

# %% [markdown]
# ### Encapsulation

# %%
class BankAccout:
    def __init__(self, name, bank_id, balance):
        self.name = name # public by default
        self.bank_id = bank_id
        self.balance = balance
        
acc1 = BankAccout("krish", 1234, 10_000)
print(acc1.name)
print(acc1.balance)
# Out:
# krish
# 10000

# %%
# Making Protected (use _)
class BankAccout:
    def __init__(self, name, bank_id, balance):
        self.name = name  # public by default
        self.bank_id = bank_id
        self._balance = balance # protected attribute


acc1 = BankAccout("krish", 1234, 10_000)
print(acc1.name)
print(acc1._balance)
# Out:
# krish
# 10000

# %%
# Making private (use __)
class BankAccout:
    def __init__(self, name, bank_id, balance):
        self.name = name  # public by default
        self.bank_id = bank_id
        self.__balance = balance  # private attribute - data mangling


acc1 = BankAccout("krish", 1234, 10_000)
print(acc1.name)
print(acc1.__balance)

# python data hiding by convention not inforced by python itself
# Out:
# krish
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 11
#       9 acc1 = BankAccout("krish", 1234, 10_000)
#      10 print(acc1.name)
# ---> 11 print(acc1.__balance)
#
# AttributeError: 'BankAccout' object has no attribute '__balance'

# %%
# Getters and Setters to access private data 
class BankAccount:
    def __init__(self, name, bank_id, balance):
        self.name = name  # public by default
        self.bank_id = bank_id
        self.__balance = balance  # protected attribute
        
    def get_balance(self): # getter
        print("Your balance is ", self.__balance)
        
    def set_balance(self, balance): # setter
        self.__balance = balance


acc1 = BankAccount("krish", 1234, 10_000)
print(acc1.name)
acc1.get_balance()
acc1.set_balance(30_000_000)
acc1.get_balance()

# access the private data outside class directly
print(acc1._BankAccount__balance)
# Out:
# krish
# Your balance is  10000
# Your balance is  30000000
# 30000000

# %% [markdown]
# ### Inheritance

# %%
class Employee:
    start_time = '10 AM'
    end_time = '5 PM'
    
    def get_time(self):
        print(self.start_time, self.end_time)
    
    def change_time(self, new_time):
        self.start_time = new_time
    
class Teacher(Employee):
    def __init__(self, subject, name, t_id):
        self.subject = subject
        self.name = name
        self.t_id = t_id
        
class Admin_staff (Employee):
    def __init__(self, role):
        self.role = role
    
        
        
t1 = Teacher("math", "krish", 123)
print(t1.name, t1.start_time, t1.end_time, t1.subject)

t1.get_time()
t1.change_time("8 AM")
t1.get_time()

staff_1 = Admin_staff("Director")
staff_2 = Admin_staff("Manager")
print(staff_1.role, staff_1.start_time, staff_1.end_time)
print(staff_2.role, staff_2.start_time, staff_2.end_time)

staff_2.change_time("11 AM")
print(staff_2.role, staff_2.start_time, staff_2.end_time)
# Out:
# krish 10 AM 5 PM math
# 10 AM 5 PM
# 8 AM 5 PM
# Director 10 AM 5 PM
# Manager 10 AM 5 PM
# Manager 11 AM 5 PM

# %% [markdown]
# ### Types of inheritance

# %%
# Multilevel Inheritance

class Employee:
    start_time="10 AM"
    end_time="6 PM"
    
class Admin_staff(Employee):
    def __init__(self, role):
        
        self.role = role
        
class Accountant(Admin_staff):
    def __init__(self, salary, role):
        super().__init__(role)
        self.salary = salary
        
acc1 = Accountant(25_000, "CA")

print(acc1.salary)
print(acc1.role)
print(acc1.start_time)
# Out:
# 25000
# CA
# 10 AM

# %%
# Multiple Inheritance
class Teacher:
    def __init__(self, subject, salary):
        self.subject = subject
        self.salary = salary


class Student:
    def __init__(self, fees, year):
        self.fees = fees
        self.year = year


class TA(Teacher, Student):
    def __init__(self, name, fees, year, subject, salary):
        super().__init__(subject, salary)
        Student.__init__(self, fees, year)
        self.name = name


t1 = TA("krish", 10_000, 4, "Robotics", 50_000)
print(t1.name)
print(t1.subject)
print(t1.salary)
print(t1.fees)
print(t1.year)
# Out:
# krish
# Robotics
# 50000
# 10000
# 4

# %%
# Abstraction
from abc import ABC, abstractmethod  ## abstraction base classes


class Animal(ABC):
    @abstractmethod
    def make_sound(self):
        pass


class Lion(Animal):
    def make_sound(self):
        print("Roar!")


class Cow(Animal):
    def make_sound(self):
        print("Moo!")


class Cat(Animal):
    def make_sound(self):
        print("Meou")


lion = Lion()
lion.make_sound()

cow = Cow()
cow.make_sound()

cat = Cat()
cat.make_sound()
# Out:
# Roar!
# Moo!
# Meou

# %%
# Polymorphism

# 1. operator overloading
print(1+2, "krish" + "kumar")

# 2. function overriding (it done where inheritance is involved)
class Employee:
    def get_designation(self):
        print("Designation = Employee")
        
class Teacher(Employee):
    def get_designation(self):
        print("Designation = Teacher")
        
class Accountant(Teacher):
    def get_designation(self):
        print("Designation = Accountant")
        
e = Employee()
e.get_designation()

t = Teacher()
t.get_designation()

a = Accountant()
a.get_designation()
# Out:
# 3 krishkumar
# Designation = Employee
# Designation = Teacher
# Designation = Accountant

# %%
# Duck Typing
class Teacher():
    def get_designation(self):
        print("Designation = Teacher")
        
class Accountant():
    def get_designation(self):
        print("Designation = Accountant")
        
t = Teacher()
t.get_designation()

a = Accountant()
a.get_designation()
# Out:
# Designation = Teacher
# Designation = Accountant
