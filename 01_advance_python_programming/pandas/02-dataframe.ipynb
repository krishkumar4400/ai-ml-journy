# %% [markdown]
# ## Contents
# - Creating a Dataframe
# - Selection and indexing of columns
# - Creating a new column
# - Removing columns
# - Selecting rows
# - Selecting subsets of Rows and columns
# - conditional selection

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Creating a Dataframe

# %%
data = {
    "Name": ["John", "Anna", "Peter", "Linda"],
    "Age": [28, 34, 29, 42],
    "City": ["New York", "Paris", "Berlin", "London"],
    "Salary": [65000, 70000, 62000, 85000],
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ["John", 28, "New York", 65000],
    ["Anna", 34, "Paris", 70000],
    ["Peter", 29, "Berlin", 62000],
    ["Linda", 42, "London", 85000],
]

df2 = pd.DataFrame(data_list)

# %%
df2
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
columns = ["Name", "Age", "City", "Salary"]
df3 = pd.DataFrame(data_list, columns=columns)

# %%
df3
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# Selection and indexing of columns

# %%
df3
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df3['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
df3['City']
# Out:
# 0    New York
# 1       Paris
# 2      Berlin
# 3      London
# Name: City, dtype: object

# %%
df3[["Name", "City", "Age"]]
# Out:
#     Name      City  Age
# 0   John  New York   28
# 1   Anna     Paris   34
# 2  Peter    Berlin   29
# 3  Linda    London   42

# %% [markdown]
# Creating a new column

# %%
df3
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df3['Address'] = ["Meerut", "Bhagalpur", "Surat", "Delhi"]

# %%
df3
# Out:
#     Name  Age      City  Salary    Address
# 0   John   28  New York   65000     Meerut
# 1   Anna   34     Paris   70000  Bhagalpur
# 2  Peter   29    Berlin   62000      Surat
# 3  Linda   42    London   85000      Delhi

# %%
df3[["Designation", "Experience"]] = pd.DataFrame({
    "Designation": ["Doctor", "Engineer", "Scientist", "IAS"],
    "Experience": [2, 3, 4, 5],
})

# %%
df3
# Out:
#     Name  Age      City  Salary    Address Designation  Experience
# 0   John   28  New York   65000     Meerut      Doctor           2
# 1   Anna   34     Paris   70000  Bhagalpur    Engineer           3
# 2  Peter   29    Berlin   62000      Surat   Scientist           4
# 3  Linda   42    London   85000      Delhi         IAS           5

# %%
col = df3.drop("Age", axis=1)
col
# Out:
#     Name      City  Salary    Address Designation  Experience
# 0   John  New York   65000     Meerut      Doctor           2
# 1   Anna     Paris   70000  Bhagalpur    Engineer           3
# 2  Peter    Berlin   62000      Surat   Scientist           4
# 3  Linda    London   85000      Delhi         IAS           5

# %%
df3.drop("Name", axis=1)
# Out:
#    Age      City  Salary    Address Designation  Experience
# 0   28  New York   65000     Meerut      Doctor           2
# 1   34     Paris   70000  Bhagalpur    Engineer           3
# 2   29    Berlin   62000      Surat   Scientist           4
# 3   42    London   85000      Delhi         IAS           5

# %%
df3
# Out:
#     Name  Age      City  Salary    Address Designation  Experience
# 0   John   28  New York   65000     Meerut      Doctor           2
# 1   Anna   34     Paris   70000  Bhagalpur    Engineer           3
# 2  Peter   29    Berlin   62000      Surat   Scientist           4
# 3  Linda   42    London   85000      Delhi         IAS           5

# %%
df3 = df3.drop("City", axis=1)

# %%
df3
# Out:
#     Name  Age  Salary    Address Designation  Experience
# 0   John   28   65000     Meerut      Doctor           2
# 1   Anna   34   70000  Bhagalpur    Engineer           3
# 2  Peter   29   62000      Surat   Scientist           4
# 3  Linda   42   85000      Delhi         IAS           5

# %%
df3.drop("Address", axis=1, inplace=True)

# %%
df3
# Out:
#     Name  Age  Salary Designation  Experience
# 0   John   28   65000      Doctor           2
# 1   Anna   34   70000    Engineer           3
# 2  Peter   29   62000   Scientist           4
# 3  Linda   42   85000         IAS           5

# %%
df3
# Out:
#     Name  Age  Salary Designation  Experience
# 0   John   28   65000      Doctor           2
# 1   Anna   34   70000    Engineer           3
# 2  Peter   29   62000   Scientist           4
# 3  Linda   42   85000         IAS           5

# %%
df3.drop(["Designation", "Experience"], axis=1, inplace=True)

# %%
df3
# Out:
#     Name  Age  Salary
# 0   John   28   65000
# 1   Anna   34   70000
# 2  Peter   29   62000
# 3  Linda   42   85000

# %%
# remove row
df.drop(0, axis=0, inplace=True)
df
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 2  Peter   29  Berlin   62000
# 3  Linda   42  London   85000

# %%
df.drop([2,3], inplace=True)

# %%
df
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000

# %% [markdown]
# Selecting rows

# %%
df2
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
df2 = pd.DataFrame(data_list, columns=columns)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.loc[0]
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
df2.loc[[1,2]]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 2  Peter   29  Berlin   62000

# %%
df2.iloc[3]
# Out:
# Name       Linda
# Age           42
# City      London
# Salary     85000
# Name: 3, dtype: object

# %%
df
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000

# %% [markdown]
# Selecting subsets of rows and columns

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.loc[[0,1]][["City", "Salary"]]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df2.loc[[2,3]][["Name", "Age"]]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# Conditional Selection

# %%
# I only want to see those people whose age is above 30

df2[df2["Age"] > 30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
# i only want people whose age is above 30 and their city must be paris

df2[((df2['Age'] > 30) & (df2['City'] == 'Paris'))]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
